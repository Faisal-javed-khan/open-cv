# %%
import numpy as np
import cv2
img=cv2.imread('imrankhan.jpg')
cv2.imshow("the king of politics" , img)
cv2.waitKey(0)
cv2.destroyAllWindows()
graypic=cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)
cv2.imshow("grapy picture" , graypic)
cv2.waitKey(0)
cv2.destroyAllWindows()
# img=cv2.imread('imrankhan.jpg' , 0)
# cv2.imshow("onther way of gray" , img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# threshold(img ,127 , 255 , THRESH_BINARY)

#show pic in the form of hsv hue , saturation  , value

imghsv=cv2.cvtColor(img , cv2.COLOR_BGR2HSV)

# cv2.imshow("imghsv full " , imghsv)
cv2.imshow("hsv pic 0 show he hsv   " , imghsv[: ,: ,0])
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imshow("saturation pic  1 show saturation" , imghsv[: ,: ,1])
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imshow("value pic 2 show value" , imghsv[: ,: ,2])
cv2.waitKey(0)
cv2.destroyAllWindows()

#split the picture in to layers red green blue
b,g,r=cv2.split(img)
zeros=np.zeros(img.shape[:2] , dtype="uint8")
cv2.imshow("red" , cv2.merge([zeros , zeros , r]))
cv2.waitKey(0)
cv2.destroyAllWindows()

cv2.imshow("green" , cv2.merge([zeros , g , zeros]))
cv2.waitKey(0)
cv2.destroyAllWindows()

cv2.imshow("blue" , cv2.merge([b , zeros , zeros]))
cv2.waitKey(0)
cv2.destroyAllWindows()

img3=cv2.imread("animal.JFIF")
print("it will show all height width and layers=" ,img3[100 , 100])
print("it will show only height=" , img3[100 , 100 , 0])
print("it will show only width=" , img3[100 , 100 , 1])
print("it will show only layrs=" , img3[100 , 100 , 2])
cv2.imshow("orignal anial px=" , img3)
img3[100 , 100]=[255 ,255 , 255]
cv2.waitKey(0)
cv2.destroyAllWindows()
print("size have how many ppixel rows colnm  and channels" ,img3.size)

# #split the pic in rgb
# Interpolation(optional) – This flag uses following methods:
# INTER_NEAREST – a nearest-neighbor interpolation
# INTER_LINEAR – a bilinear interpolation (used by default) 
# INTER_AREA – resampling using pixel area relation. It may be a preferred method for image decimation, as it gives moire’-free results. But when the image is zoomed, it is similar to the INTER_NEAREST method.
# INTER_CUBIC – a bicubic interpolation over 4×4 pixel neighborhood 
# INTER_LANCZOS4 – a Lanczos interpolation over 8×8 pixel neighborhood


#image resize 
imgresize=cv2.resize(img3 ,(400 , 600), interpolation=cv2.INTER_NEAREST)
cv2.imshow( "resize pic = " , img3)
cv2.waitKey(0)
cv2.destroyAllWindows()
imagerotate=cv2.rotate(img3 ,cv2.ROTATE_90_CLOCKWISE)
cv2.imshow("rotate pic 90 clockwise =" , imagerotate)
cv2.waitKey(0)
cv2.destroyAllWindows()

imagerotate=cv2.rotate(img3 ,cv2.ROTATE_90_COUNTERCLOCKWISE)
cv2.imshow("rotate pic anticlockwise 90 =" , imagerotate)
cv2.waitKey(0)
cv2.destroyAllWindows()

imagerotate=cv2.rotate(img3 ,cv2.ROTATE_180)
cv2.imshow("rotate pic clockwise 180 =" , imagerotate)
cv2.waitKey(0)
cv2.destroyAllWindows()

#resixze 
resize=cv2.resize(img , (500 , 500))
cv2.imshow("reisze image:" , resize)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# it will show all height width and layers= [103 128 130]
# it will show only height= 103
# it will show only width= 128
# it will show only layrs= 130
# size have how many ppixel rows colnm  and channels 151248

# %%
import numpy as np
import cv2
img=cv2.imread('imrankhan.jpg')
cv2.imshow("the king of politics" , img)
cv2.waitKey(0)
cv2.destroyAllWindows()    #image   text      placed         font type      sclae txt    color       thickness       
# textimage=cv2.putText(img , "i am khan " , (100 , 140), cv2.FONT_HERSHEY_TRIPLEX , 2 , (0, 255 , 0) , 2)
# # Hershey Simplex
# # Hershey Plain
# # Hershey Duplex
# # Hershey Complex
# # Hershey Triplex
# # Hershey Complex Small
# # Hershey Script Simplex
# # Hershey Script Complex
# cv2.imshow("texted image " , textimage)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

#line draing on image        strt poitn   end point     color      thickjness
lineimage=cv2.line(img , (100 , 100) , (250 , 243) , (250 , 0 , 0) ,3)
cv2.imshow("line drawing" , lineimage)
cv2.waitKey(0)
cv2.destroyAllWindows()


#rectangle drawaing     img     str point    last point     color       thicknees
rectimage=cv2.rectangle(img ,(100 , 100) , (200 , 200) , (0 , 0 ,255) , 3 )
cv2.imshow("rectangle image" , rectimage)
cv2.waitKey(0)
cv2.destroyAllWindows()

#circle drawing 
circleimage=cv2.circle(img , (300 , 200) , 60 , (0 , 255 , 0) , 3)
cv2.imshow("circle " , circleimage)
cv2.waitKey(0)
cv2.destroyAllWindows()

imghsv=cv2.cvtColor(img , cv2.COLOR_BGR2HSV)
cv2.imshow("hsv " , imghsv)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv
cap = cv.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    exit()
while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    # if frame is read correctly ret is True
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    # Our operations on the frame come here
    gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    
    
    # Display the resulting frame
    cv.imshow('frame', gray)
    if cv.waitKey(1) == ord('d'):
        break
# When everything done, release the capture
cap.release()
cv.waitKey(0)
cv.destroyAllWindows()

# %%
capture=cv.VideoCapture(0)
while True:
    ret , fram=capture.read()
    cv.imshow("reading the frames",  fram)
    graypic=cv.cvtColor(fram , cv.COLOR_BGR2GRAY)
    hsv=cv.cvtColor(fram , cv.COLOR_BGR2HSV)
    cv.imshow("reading the grays frames",  graypic)
    cv.imshow("reading the HSV frames",  hsv)
    if cv.waitKey(1)==ord('d'):
        break
capture.release()
cv.waitKey(0)
cv.destroyAllWindows()

# %%
from matplotlib import pyplot as plt
import cv2 as cv
vidos=cv.VideoCapture("cat.mp4")
while(vidos.isOpened()):
    ret, frames=vidos.read()
#     cv.imwrite("newpic.jpg" , frames)
    frames=cv.resize(frames ,(400 , 600))
    cv.imshow("vido" , frames)
    if cv.waitKey(20)==ord('d'):
        break
vidos.release()
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv
cap = cv.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    exit()
while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    # if frame is read correctly ret is True
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    # Our operations on the frame come here
    gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    
    ###convert image to binary
ret , thresh=cv.threshold(gray , 127 , 255 , cv.THRESH_BINARY)
##find contours in binary img
contours , hie=cv.findContours(thresh, cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)

cv.drawContours(frame , contours, -1,(255,0,0),2)
    
    
    # Display the resulting frame
cv.imshow('frame', frame)
if cv.waitKey(1) == ord('d'dd:
        break
# When everything done, release the capture
cap.release()
cv.waitKey(0)
cv.destroyAllWindows()
